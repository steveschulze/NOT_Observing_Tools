# %%
# %load_ext autoreload
# %autoreload 2

from   astropy.visualization import astropy_mpl_style, quantity_support
from   plotsettings import *
from   routines_not import *
from   standard_libraries import *

plt.style.use(astropy_mpl_style)
quantity_support()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <astropy.visualization.units.quantity_support.<locals>.MplQuantityConverter at 0x7f7774b171c0>

# %% [markdown]
# # Night

# %%
date = '2022-08-08'
#utcoffset_lapalma = +1*u.hour  # La Palma time zone to UTC
#time_utc     = time.Time('2022-07-12 23:00:00') - utcoffset_lapalma

# %% [markdown]
# # Objects

# %%
list_object       = ascii.read('targets.ascii')
list_object
# Out:
# <Table length=5>
#     NAME          RA         DEC
#    str12        str11       str12
# ------------ ----------- ------------
# ZTF18acjpret 19:01:41.90 +40:45:03.67
# ZTF22aaemvhi 16:53:57.61 -09:42:10.12
# ZTF22aamgumi 19:15:23.62 +48:19:27.78
# ZTF22aaspkif 21:56:40.95 -09:30:52.42
# ZTF22aaetqeo 18:28:40.83 +20:28:48.90

# %%
plot_objects(date, list_object, OBS=obs_NOT, SAVE=False)
# Out:
# ZTF18acjpret
# Moon separation = 69 deg, fli = 86%
# ZTF22aaemvhi
# Moon separation = 26 deg, fli = 86%
# ZTF22aamgumi
# Moon separation = 77 deg, fli = 86%
# ZTF22aaspkif
# Moon separation = 56 deg, fli = 86%
# ZTF22aaetqeo
# Moon separation = 48 deg, fli = 86%

# %% [markdown]
# # Standard stars

# %%
plot_standards(date, OBS=obs_NOT, SAVE=False)
# Out:
# SP1036+433
# Moon separation = 125 deg, fli = 86%
# SP1045+378
# Moon separation = 122 deg, fli = 86%
# SP1446+259
# Moon separation = 72 deg, fli = 86%
# SP1550+330
# Moon separation = 69 deg, fli = 86%
# SP2209+178
# Moon separation = 74 deg, fli = 86%
# SP2317-054
# Moon separation = 76 deg, fli = 86%
